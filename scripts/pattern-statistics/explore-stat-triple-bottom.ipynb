# %% [markdown]
# # Calculating Statistics For Patterns

# %% [markdown]
# ## Proportional Test

# %%
import pandas as pd

csv_dir = "~/Projects/strategy-evaluator/output/csv"
pattern_name = "triple-bottom"
eval_name = "barriers"
eval_type = "wins"
table_name = "by-range"

# %%
def load_results(tdir: str, etype: str, rtype: str, estrat: str, pname: str) -> (pd.DataFrame, pd.DataFrame):
    wins_table_path = f"{tdir}/{etype}/{rtype}_{estrat}_{pname}.csv"
    size_table_path = f"{tdir}/size/{rtype}_{estrat}_{pname}.csv"
    df_pattern_wins = pd.read_csv(wins_table_path, delimiter=',', index_col=0)
    df_pattern_size = pd.read_csv(size_table_path, delimiter=',', index_col=0)
    return df_pattern_wins, df_pattern_size

# %%
pattern_wins, pattern_size = load_results(csv_dir, eval_type, table_name, eval_name, pattern_name)
pattern_rate = pattern_wins / pattern_size
print(pattern_name, eval_name, eval_type, table_name)
display(pattern_rate)
# Out:
# triple-bottom barriers wins by-range
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0.511590  0.518547  0.520365  0.525029   0.486056   0.487952  \
# thld:0.020  0.525276  0.530117  0.540103  0.546482   0.505263   0.516234
# thld:0.025  0.529601  0.543235  0.537143  0.538988   0.527650   0.539286
# thld:0.030  0.532040  0.545759  0.529270  0.528481   0.535714   0.561983
# thld:0.035  0.534776  0.545244  0.522181  0.534050   0.552239   0.577670
# thld:0.040  0.531358  0.547435  0.527778  0.521186   0.552901   0.588889
# thld:0.045  0.532717  0.544676  0.525063  0.523573   0.553719   0.642857
# thld:0.050  0.535197  0.541903  0.523460  0.539359   0.567308   0.632000
# thld:0.100  0.537728  0.520833  0.520833  0.550000   0.608696   0.600000
#
#             rng:15.00  rng:17.00  rng:19.00  rng:21.00  rng:23.00  rng:25.00
# thld:0.015   0.479452   0.493056   0.509615   0.475610   0.531250   0.509434  \
# thld:0.020   0.514851   0.525926   0.525253   0.556962   0.557377   0.540000
# thld:0.025   0.531073   0.560976   0.549451   0.579710   0.563636   0.577778
# thld:0.030   0.525974   0.527273   0.566265   0.550000   0.630435   0.625000
# thld:0.035   0.529851   0.517241   0.594203   0.551020   0.600000   0.593750
# thld:0.040   0.508475   0.565789   0.571429   0.605263   0.592593   0.592593
# thld:0.045   0.542857   0.651515   0.607843   0.566667   0.576923   0.625000
# thld:0.050   0.571429   0.714286   0.636364   0.518519   0.583333   0.681818
# thld:0.100   0.538462   0.818182   0.714286   0.666667   0.500000   0.500000
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.634146   0.685714   0.600000
# thld:0.020   0.638889   0.676471   0.583333
# thld:0.025   0.666667   0.733333   0.571429
# thld:0.030   0.677419   0.714286   0.571429
# thld:0.035   0.629630   0.692308   0.550000
# thld:0.040   0.565217   0.666667   0.578947
# thld:0.045   0.619048   0.611111   0.625000
# thld:0.050   0.578947   0.562500   0.571429
# thld:0.100   0.333333   0.500000   0.666667

# %%
random_wins, random_size = load_results(csv_dir, eval_type, table_name, eval_name, "random")
random_rate = random_wins / random_size
print(pattern_name, eval_name, eval_type, "random")
display(random_rate)
# Out:
# triple-bottom barriers wins random
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0
# thld:0.100   0.007749   0.285268   0.179952   0.129638  -0.029790  -0.038269
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.157876   0.213985   0.128185
# thld:0.020   0.144991   0.185231   0.090848
# thld:0.025   0.161912   0.233731   0.065790
# thld:0.030   0.166232   0.210880   0.058007
# thld:0.035   0.114151   0.183548   0.032932
# thld:0.040   0.047956   0.154937   0.059467
# thld:0.045   0.098706   0.096191   0.102984
# thld:0.050   0.057919   0.046768   0.048550
# thld:0.100  -0.197720  -0.035213   0.134970

# %%
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multitest import multipletests

# Create a new empty DataFrame with the same dimensions as the original DataFrame
stat_table = pd.DataFrame(index=pattern_wins.index, columns=pattern_wins.columns)
p_table = stat_table.copy()

# Create an empty list to store the p-values
p_values = []

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):

        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Perform the evaluation using proportions_ztest
        stat, pval = proportions_ztest([count_pattern, count_random], [nobs_pattern, nobs_random])

        # Assign the test statistic and p-value to the new table
        stat_table.iloc[i, j] = (round(count_pattern/nobs_pattern,2), round(count_random/nobs_random,2))
        p_table.iloc[i, j] = pval

        # Append the p-value to the list
        p_values.append(pval)

# Print the new table
display(p_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015       0.0       0.0  0.000208  0.002979  0.594665  0.561388  \
# thld:0.020       0.0  0.000036  0.000242  0.003054  0.691741  0.362023
# thld:0.025       0.0   0.00001  0.012931  0.070297  0.353177  0.199377
# thld:0.030  0.000002   0.00065  0.186703   0.40868  0.345197  0.086689
# thld:0.035  0.000002   0.00735   0.68693  0.394663  0.180112  0.062485
# thld:0.040  0.000871  0.014989  0.616343  0.900327  0.215141  0.047269
# thld:0.045  0.005499  0.067329  0.781817  0.938858  0.291708  0.001926
# thld:0.050  0.023567  0.222451   0.97991   0.55192  0.175327  0.014452
# thld:0.100  0.493514   0.37609   0.74601  0.786302  0.308332  0.595372
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015    0.8744  0.611148  0.418741  0.985093  0.329314  0.585468  \
# thld:0.020  0.550625  0.411107   0.48618  0.261976  0.283244  0.501663
# thld:0.025  0.478055  0.212461  0.364628  0.218031  0.341486  0.312088
# thld:0.030  0.667033  0.746376  0.285218  0.536618  0.094171  0.133515
# thld:0.035  0.697951  0.975617  0.179974  0.616465  0.303954  0.343962
# thld:0.040  0.886113  0.399853  0.410829  0.285453   0.42474   0.41153
# thld:0.045  0.581084  0.034907  0.207772  0.617536  0.549362   0.28379
# thld:0.050  0.304235  0.004237  0.130913  0.962098  0.532368  0.126481
# thld:0.100  0.955382  0.058023  0.339986  0.652524  0.904997  0.850892
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015   0.04305  0.011244  0.199295
# thld:0.020   0.08197  0.030795  0.373466
# thld:0.025  0.062935   0.01048   0.54659
# thld:0.030  0.064184  0.025676  0.594928
# thld:0.035  0.235438  0.061272  0.768262
# thld:0.040  0.645439  0.155602  0.603982
# thld:0.045  0.365395  0.414297  0.409666
# thld:0.050  0.613405  0.708231  0.716144
# thld:0.100  0.492618  0.887731  0.639475

# %%
import matplotlib.pyplot as plt

sp_table = p_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/p_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()

# %%
# Perform the Bonferroni correction
rejected, corrected_p_values, _, _ = multipletests(p_values, method='bonferroni')
rejected
# Out:
# array([ True,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
import numpy as np

# Create a new empty DataFrame for effect sizes
h_table = stat_table.copy()

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):
        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Compute the proportions
        prop_pattern = count_pattern / nobs_pattern
        prop_random = count_random / nobs_random

        # Compute Cohen's h for the effect size
        h = 2 * np.arcsin(np.sqrt(prop_pattern)) - 2 * np.arcsin(np.sqrt(prop_random))

        # Assign the effect size to the new table
        h_table.iloc[i, j] = h

# Print the new table
display(h_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015  0.082836   0.08711  0.092856   0.10212  0.023856  0.031958  \
# thld:0.020  0.068337  0.070716  0.094897  0.105983  0.018281  0.052099
# thld:0.025  0.054439  0.078424  0.067488  0.067545  0.044799  0.077004
# thld:0.030  0.050836  0.064603  0.037939  0.033122  0.047934  0.110736
# thld:0.035  0.054137  0.054434  0.012416  0.036311  0.073686  0.130704
# thld:0.040  0.040813  0.053412  0.016586  0.005802  0.072851  0.149102
# thld:0.045  0.036607  0.043513  0.009919  0.003844  0.068162  0.254345
# thld:0.050  0.031933  0.031429  0.000975   0.03233  0.094611  0.222125
# thld:0.100   0.02036 -0.048919 -0.027141  0.035141   0.15186  0.119725
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015  0.010702  0.042393  0.079267  0.002065  0.121877  0.074871  \
# thld:0.020  0.042081  0.070852   0.07007  0.126545  0.137697  0.095142
# thld:0.025  0.053463   0.11287  0.095288  0.149071  0.128686  0.151394
# thld:0.030  0.034746  0.030892  0.117789  0.079979  0.249944      0.24
# thld:0.035  0.033602   0.00328  0.162623  0.071735  0.175131  0.168441
# thld:0.040 -0.013203  0.096985  0.110408  0.174821  0.154666  0.159111
# thld:0.045  0.054005  0.264481  0.178086  0.091511  0.117989  0.221433
# thld:0.050  0.108274  0.396423  0.231129 -0.009148  0.128176  0.334199
# thld:0.100  0.015535  0.623899  0.374189  0.265711 -0.059615 -0.076613
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015  0.319097  0.437118  0.257758
# thld:0.020  0.293684  0.378234  0.182477
# thld:0.025  0.330327  0.486314   0.13207
# thld:0.030  0.340366  0.436099  0.116501
# thld:0.035  0.231292  0.377271  0.066024
# thld:0.040  0.096277  0.316376  0.119587
# thld:0.045   0.19971  0.194248  0.208634
# thld:0.050  0.116489  0.093859  0.097575
# thld:0.100 -0.401984 -0.070483  0.276401

# %%
import matplotlib.pyplot as plt

sp_table = h_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/h_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()
