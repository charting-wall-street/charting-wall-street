# %% [markdown]
# # Calculating Statistics For Patterns

# %% [markdown]
# ## Proportional Test

# %%
import pandas as pd

csv_dir = "~/Projects/strategy-evaluator/output/csv"
pattern_name = "triple-top"
eval_name = "barriers"
eval_type = "wins"
table_name = "by-range"

# %%
def load_results(tdir: str, etype: str, rtype: str, estrat: str, pname: str) -> (pd.DataFrame, pd.DataFrame):
    wins_table_path = f"{tdir}/{etype}/{rtype}_{estrat}_{pname}.csv"
    size_table_path = f"{tdir}/size/{rtype}_{estrat}_{pname}.csv"
    df_pattern_wins = pd.read_csv(wins_table_path, delimiter=',', index_col=0)
    df_pattern_size = pd.read_csv(size_table_path, delimiter=',', index_col=0)
    return df_pattern_wins, df_pattern_size

# %%
pattern_wins, pattern_size = load_results(csv_dir, eval_type, table_name, eval_name, pattern_name)
pattern_rate = pattern_wins / pattern_size
print(pattern_name, eval_name, eval_type, table_name)
display(pattern_rate)
# Out:
# triple-top barriers wins by-range
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0.505062  0.496513  0.517454  0.480732   0.458333   0.502513  \
# thld:0.020  0.517368  0.512083  0.515314  0.495050   0.468591   0.518229
# thld:0.025  0.519004  0.506586  0.524504  0.501650   0.500000   0.531250
# thld:0.030  0.519257  0.508131  0.527851  0.508861   0.494505   0.548387
# thld:0.035  0.525367  0.513004  0.528517  0.508721   0.510101   0.567669
# thld:0.040  0.529374  0.526296  0.527354  0.506920   0.521866   0.570815
# thld:0.045  0.525462  0.526339  0.534884  0.531959   0.525952   0.551724
# thld:0.050  0.529446  0.524078  0.525799  0.537897   0.533898   0.562130
# thld:0.100  0.537112  0.497797  0.511111  0.517647   0.534884   0.545455
#
#             rng:15.00  rng:17.00  rng:19.00  rng:21.00  rng:23.00  rng:25.00
# thld:0.015   0.544747   0.520408   0.500000   0.480769   0.461538   0.430769  \
# thld:0.020   0.570213   0.500000   0.543307   0.463918   0.444444   0.448276
# thld:0.025   0.585586   0.506173   0.534483   0.472527   0.426471   0.410714
# thld:0.030   0.570000   0.523810   0.552381   0.506329   0.456140   0.428571
# thld:0.035   0.590361   0.546154   0.523256   0.478261   0.448980   0.418605
# thld:0.040   0.625000   0.584071   0.526316   0.483333   0.418605   0.447368
# thld:0.045   0.619403   0.572917   0.573529   0.509804   0.475000   0.500000
# thld:0.050   0.641026   0.595506   0.564516   0.531915   0.500000   0.538462
# thld:0.100   0.642857   0.578947   0.500000   0.571429   0.428571   0.600000
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.528302   0.414634   0.545455
# thld:0.020   0.469388   0.315789   0.600000
# thld:0.025   0.458333   0.324324   0.517241
# thld:0.030   0.487805   0.375000   0.464286
# thld:0.035   0.486486   0.321429   0.464286
# thld:0.040   0.457143   0.307692   0.454545
# thld:0.045   0.451613   0.347826   0.450000
# thld:0.050   0.615385   0.411765   0.562500
# thld:0.100   0.833333   0.750000   0.750000

# %%
random_wins, random_size = load_results(csv_dir, eval_type, table_name, eval_name, "random")
random_rate = random_wins / random_size
print(pattern_name, eval_name, eval_type, "random")
display(random_rate)
# Out:
# triple-top barriers wins random
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0
#
#             rng:15.00  rng:17.00  rng:19.00  rng:21.00  rng:23.00  rng:25.00
# thld:0.015   0.070640   0.048534   0.030000   0.006191  -0.008811  -0.041244  \
# thld:0.020   0.076399   0.009488   0.053078  -0.029896  -0.044212  -0.044196
# thld:0.025   0.081224   0.001480   0.032595  -0.032989  -0.072996  -0.091684
# thld:0.030   0.061388   0.011970   0.044815  -0.003764  -0.050849  -0.077769
# thld:0.035   0.077295   0.030552   0.009799  -0.036979  -0.064132  -0.091482
# thld:0.040   0.109926   0.066586   0.009849  -0.035309  -0.097190  -0.066205
# thld:0.045   0.103498   0.051228   0.053880  -0.011300  -0.043231  -0.015621
# thld:0.050   0.123492   0.072270   0.041975   0.008827  -0.019631   0.019481
# thld:0.100   0.112144   0.046033  -0.034334   0.034400  -0.101219   0.061731
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.052031  -0.057095   0.073640
# thld:0.020  -0.024511  -0.175450   0.107514
# thld:0.025  -0.046422  -0.175278   0.011603
# thld:0.030  -0.023382  -0.128406  -0.049136
# thld:0.035  -0.028992  -0.187331  -0.052783
# thld:0.040  -0.060119  -0.204037  -0.064935
# thld:0.045  -0.068728  -0.167094  -0.072016
# thld:0.050   0.094356  -0.103967   0.039622
# thld:0.100   0.302280   0.214787   0.218303

# %%
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multitest import multipletests

# Create a new empty DataFrame with the same dimensions as the original DataFrame
stat_table = pd.DataFrame(index=pattern_wins.index, columns=pattern_wins.columns)
p_table = stat_table.copy()

# Create an empty list to store the p-values
p_values = []

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):

        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Perform the evaluation using proportions_ztest
        stat, pval = proportions_ztest([count_pattern, count_random], [nobs_pattern, nobs_random])

        # Assign the test statistic and p-value to the new table
        stat_table.iloc[i, j] = (round(count_pattern/nobs_pattern,2), round(count_random/nobs_random,2))
        p_table.iloc[i, j] = pval

        # Append the p-value to the list
        p_values.append(pval)

# Print the new table
display(p_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015       0.0  0.005245  0.000162  0.666859  0.432012  0.224355  \
# thld:0.020       0.0  0.028782  0.055424  0.925265  0.184048  0.273557
# thld:0.025  0.000602  0.762127  0.086613  0.829572  0.808497  0.255371
# thld:0.030  0.013416  0.538993  0.180414  0.864006  0.463431  0.144208
# thld:0.035  0.001102  0.586627  0.370441  0.707976  0.830933  0.073454
# thld:0.040  0.001437  0.584301  0.604671  0.587328  0.845152  0.088148
# thld:0.045  0.074566  0.756288  0.369499  0.651896   0.83322   0.33339
# thld:0.050  0.125166  0.853752  0.873434  0.555101  0.674812  0.303815
# thld:0.100  0.489131  0.046634  0.534601  0.784661  0.986723  0.957006
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015  0.023693  0.174326  0.480728  0.899496  0.876201  0.505627  \
# thld:0.020  0.019444   0.80156  0.232083  0.556297   0.45329  0.501039
# thld:0.025  0.015744  0.969999  0.483133  0.529473  0.228972  0.170255
# thld:0.030  0.083159  0.771923  0.358905  0.946683  0.442857   0.27649
# thld:0.035  0.046763  0.486476  0.855874  0.539148  0.369388  0.230378
# thld:0.040  0.006804  0.157249  0.863715  0.584417  0.202474  0.414436
# thld:0.045  0.016722  0.315659  0.374307  0.871764  0.584461  0.855451
# thld:0.050  0.007625  0.172842  0.508588  0.903642  0.813728  0.842474
# thld:0.100  0.234974  0.687794  0.827769  0.855213  0.591691  0.781918
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015   0.44843  0.464137  0.396928
# thld:0.020  0.731598  0.030573  0.238985
# thld:0.025  0.520268  0.033048  0.900575
# thld:0.030  0.764657  0.146433  0.603047
# thld:0.035  0.724301  0.047464  0.576346
# thld:0.040  0.476822  0.037469  0.542242
# thld:0.045   0.44391  0.108963  0.519209
# thld:0.050  0.335698  0.391156  0.751072
# thld:0.100  0.137978  0.389158  0.381667

# %%
import matplotlib.pyplot as plt

sp_table = p_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/p_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()

# %%
# Perform the Bonferroni correction
rejected, corrected_p_values, _, _ = multipletests(p_values, method='bonferroni')
rejected
# Out:
# array([ True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
import numpy as np

# Create a new empty DataFrame for effect sizes
h_table = stat_table.copy()

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):
        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Compute the proportions
        prop_pattern = count_pattern / nobs_pattern
        prop_random = count_random / nobs_random

        # Compute Cohen's h for the effect size
        h = 2 * np.arcsin(np.sqrt(prop_pattern)) - 2 * np.arcsin(np.sqrt(prop_random))

        # Assign the effect size to the new table
        h_table.iloc[i, j] = h

# Print the new table
display(h_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015  0.069778  0.043033  0.087029  0.013496 -0.031683  0.061081  \
# thld:0.020  0.052506  0.034613  0.045238  0.002982 -0.055105  0.056092
# thld:0.025  0.033219  0.005017  0.042162 -0.007209 -0.010528  0.060892
# thld:0.030  0.025237 -0.010781  0.035097 -0.006148 -0.034544  0.083375
# thld:0.035  0.035286 -0.010166  0.025104 -0.014399  -0.01078  0.110488
# thld:0.040  0.036838  0.011014  0.015737 -0.022742  0.010596  0.112483
# thld:0.045  0.022071  0.006743  0.029597  0.020641  0.012443  0.068227
# thld:0.050  0.020406 -0.004301  0.005657  0.029398  0.027434   0.07954
# thld:0.100  0.019124 -0.095003 -0.046596 -0.029725  0.002543  0.009402
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015  0.141424   0.09711  0.060035  0.012394 -0.017663 -0.082906  \
# thld:0.020  0.153264  0.018976  0.106267 -0.059855 -0.088651 -0.088577
# thld:0.025  0.163294   0.00296  0.065246 -0.066005 -0.146527  -0.18433
# thld:0.030  0.123236  0.023956  0.089822  -0.00753 -0.101811 -0.156028
# thld:0.035  0.155586   0.06123  0.019612 -0.073976 -0.128446 -0.183693
# thld:0.040  0.222527  0.133967  0.019717 -0.070632 -0.195113 -0.132608
# thld:0.045  0.209321  0.102965  0.108286 -0.022611 -0.086491 -0.031247
# thld:0.050  0.250858  0.145705  0.084295   0.01768 -0.039272  0.039029
# thld:0.100  0.228287  0.092682 -0.068722  0.069222 -0.202963  0.124745
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015  0.104111 -0.115001  0.147435
# thld:0.020 -0.049059 -0.359788  0.216387
# thld:0.025  -0.09294 -0.358218  0.023212
# thld:0.030 -0.046768 -0.259492 -0.098336
# thld:0.035 -0.057993 -0.382727 -0.105633
# thld:0.040  -0.12035 -0.418252 -0.130006
# thld:0.045  -0.13762 -0.339099 -0.144214
# thld:0.050  0.190799 -0.208869  0.079556
# thld:0.100  0.667581  0.453115  0.460163

# %%
import matplotlib.pyplot as plt

sp_table = h_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/h_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()
