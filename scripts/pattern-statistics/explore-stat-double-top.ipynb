# %% [markdown]
# # Calculating Statistics For Patterns

# %% [markdown]
# ## Proportional Test

# %%
import pandas as pd

csv_dir = "~/Projects/strategy-evaluator/output/csv"
pattern_name = "double-top"
eval_name = "barriers"
eval_type = "wins"
table_name = "by-range"

# %%
def load_results(tdir: str, etype: str, rtype: str, estrat: str, pname: str) -> (pd.DataFrame, pd.DataFrame):
    wins_table_path = f"{tdir}/{etype}/{rtype}_{estrat}_{pname}.csv"
    size_table_path = f"{tdir}/size/{rtype}_{estrat}_{pname}.csv"
    df_pattern_wins = pd.read_csv(wins_table_path, delimiter=',', index_col=0)
    df_pattern_size = pd.read_csv(size_table_path, delimiter=',', index_col=0)
    return df_pattern_wins, df_pattern_size

# %%
pattern_wins, pattern_size = load_results(csv_dir, eval_type, table_name, eval_name, pattern_name)
pattern_rate = pattern_wins / pattern_size
print(pattern_name, eval_name, eval_type, table_name)
display(pattern_rate)
# Out:
# double-top barriers wins by-range
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0.489760  0.493292  0.491047  0.499172   0.498401   0.486813  \
# thld:0.020  0.503641  0.509822  0.507928  0.516385   0.513518   0.506212
# thld:0.025  0.512032  0.518060  0.515604  0.524239   0.519241   0.511403
# thld:0.030  0.515951  0.520715  0.519975  0.525969   0.523108   0.511093
# thld:0.035  0.518112  0.525659  0.525290  0.530109   0.523664   0.512546
# thld:0.040  0.520830  0.525216  0.525592  0.532594   0.525717   0.514977
# thld:0.045  0.522186  0.526453  0.526583  0.534218   0.524674   0.513192
# thld:0.050  0.523947  0.525581  0.527354  0.536859   0.528893   0.514318
# thld:0.100  0.529418  0.524250  0.527559  0.533424   0.509413   0.504496
#
#             rng:15.00  rng:17.00  rng:19.00  rng:21.00  rng:23.00  rng:25.00
# thld:0.015   0.487481   0.478349   0.479960   0.484068   0.477749   0.474557  \
# thld:0.020   0.499950   0.491425   0.495114   0.498151   0.502065   0.499047
# thld:0.025   0.508325   0.500849   0.503227   0.507934   0.507672   0.510199
# thld:0.030   0.510460   0.505143   0.509517   0.518962   0.514096   0.511330
# thld:0.035   0.508567   0.510687   0.512547   0.524878   0.511827   0.510143
# thld:0.040   0.507750   0.510445   0.508252   0.529777   0.516662   0.508413
# thld:0.045   0.508100   0.514093   0.512086   0.523624   0.513628   0.503149
# thld:0.050   0.501762   0.510191   0.514694   0.524843   0.514421   0.498952
# thld:0.100   0.487647   0.491791   0.507463   0.509927   0.503589   0.476127
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.478796   0.495863   0.484829
# thld:0.020   0.499596   0.511772   0.498682
# thld:0.025   0.508117   0.517371   0.514015
# thld:0.030   0.511434   0.520123   0.526036
# thld:0.035   0.512319   0.525827   0.527100
# thld:0.040   0.515414   0.530210   0.525688
# thld:0.045   0.516978   0.528591   0.520576
# thld:0.050   0.510506   0.527473   0.517019
# thld:0.100   0.483920   0.486911   0.457086

# %%
random_wins, random_size = load_results(csv_dir, eval_type, table_name, eval_name, "random")
random_rate = random_wins / random_size
print(pattern_name, eval_name, eval_type, "random")
display(random_rate)
# Out:
# double-top barriers wins random
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00  rng:11.00  rng:13.00
# thld:0.015  0
#
#             rng:15.00  rng:17.00  rng:19.00  rng:21.00  rng:23.00  rng:25.00
# thld:0.015   0.013374   0.006476   0.009959   0.009489   0.007400   0.002543  \
# thld:0.020   0.006137   0.000913   0.004885   0.004337   0.013409   0.006575
# thld:0.025   0.003964  -0.003844   0.001340   0.002418   0.008205   0.007801
# thld:0.030   0.001848  -0.006696   0.001951   0.008868   0.007107   0.004989
# thld:0.035  -0.004499  -0.004915  -0.000910   0.009638  -0.001285   0.000056
# thld:0.040  -0.007325  -0.007040  -0.008215   0.011135   0.000867  -0.005160
# thld:0.045  -0.007805  -0.007596  -0.007563   0.002520  -0.004604  -0.012472
# thld:0.050  -0.015772  -0.013045  -0.007847   0.001754  -0.005210  -0.020029
# thld:0.100  -0.043066  -0.041123  -0.026871  -0.027102  -0.026201  -0.062142
#
#             rng:27.00  rng:29.00  rng:31.00
# thld:0.015   0.002525   0.024134   0.013014
# thld:0.020   0.005697   0.020532   0.006196
# thld:0.025   0.003362   0.017769   0.008377
# thld:0.030   0.000247   0.016717   0.012614
# thld:0.035  -0.003160   0.017067   0.010031
# thld:0.040  -0.001848   0.018480   0.006208
# thld:0.045  -0.003363   0.013671  -0.001440
# thld:0.050  -0.010522   0.011741  -0.005859
# thld:0.100  -0.047133  -0.048302  -0.074611

# %%
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multitest import multipletests

# Create a new empty DataFrame with the same dimensions as the original DataFrame
stat_table = pd.DataFrame(index=pattern_wins.index, columns=pattern_wins.columns)
p_table = stat_table.copy()

# Create an empty list to store the p-values
p_values = []

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):

        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Perform the evaluation using proportions_ztest
        stat, pval = proportions_ztest([count_pattern, count_random], [nobs_pattern, nobs_random])

        # Assign the test statistic and p-value to the new table
        stat_table.iloc[i, j] = (round(count_pattern/nobs_pattern,2), round(count_random/nobs_random,2))
        p_table.iloc[i, j] = pval

        # Append the p-value to the list
        p_values.append(pval)

# Print the new table
display(p_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015       0.0       0.0  0.000001       0.0       0.0  0.002509  \
# thld:0.020  0.000003  0.000001  0.000018       0.0   0.00011   0.00132
# thld:0.025  0.000461  0.000012  0.000873  0.000004  0.002485  0.038899
# thld:0.030  0.001091  0.029606   0.01083  0.001072  0.018096  0.417223
# thld:0.035  0.000469  0.028496  0.018888  0.001545  0.103296  0.987712
# thld:0.040  0.001526  0.223539  0.142959   0.00244  0.083345  0.977311
# thld:0.045  0.017882   0.36341   0.14087  0.011888  0.375642   0.46597
# thld:0.050  0.174364  0.873422  0.347273  0.009938  0.141922  0.211117
# thld:0.100  0.757843  0.003466  0.413755   0.92156  0.022304  0.002158
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015  0.012999  0.272299  0.118659  0.167268  0.316992  0.747397  \
# thld:0.020  0.261882  0.879012  0.451358  0.535889  0.074983  0.413549
# thld:0.025  0.480226  0.533064  0.841117  0.737373  0.289994   0.34531
# thld:0.030  0.751115  0.294999  0.778504  0.237403   0.37762  0.561745
# thld:0.035  0.460302  0.461419  0.900442  0.219332  0.878877   0.99499
# thld:0.040  0.254154  0.316749  0.283985  0.178653   0.92226  0.584549
# thld:0.045  0.250731  0.307846  0.351313  0.773392  0.624125  0.211989
# thld:0.050  0.028807   0.09967  0.361982  0.850363  0.600845  0.059276
# thld:0.100  0.000913  0.004326  0.083031  0.106303  0.142668  0.000929
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015  0.763276  0.005671  0.157073
# thld:0.020  0.503539  0.020641   0.50779
# thld:0.025  0.700821  0.052005  0.384947
# thld:0.030  0.978369  0.079659  0.208642
# thld:0.035  0.739691  0.086307  0.337693
# thld:0.040  0.853789  0.077222  0.572867
# thld:0.045  0.752028  0.218569  0.901615
# thld:0.050   0.35114  0.318899  0.637351
# thld:0.100  0.018983  0.023786  0.001059

# %%
import matplotlib.pyplot as plt

sp_table = p_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/p_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()

# %%
# Perform the Bonferroni correction
rejected, corrected_p_values, _, _ = multipletests(p_values, method='bonferroni')
rejected
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
import numpy as np

# Create a new empty DataFrame for effect sizes
h_table = stat_table.copy()

# Iterate over each cell in the DataFrame
for i in range(pattern_wins.shape[0]):
    for j in range(pattern_wins.shape[1]):
        # Get the values for the corresponding cell in the original DataFrames
        count_pattern = pattern_wins.iloc[i, j]
        nobs_pattern = pattern_size.iloc[i, j]
        count_random = random_wins.iloc[i, j]
        nobs_random = random_size.iloc[i, j]

        # Compute the proportions
        prop_pattern = count_pattern / nobs_pattern
        prop_random = count_random / nobs_random

        # Compute Cohen's h for the effect size
        h = 2 * np.arcsin(np.sqrt(prop_pattern)) - 2 * np.arcsin(np.sqrt(prop_random))

        # Assign the effect size to the new table
        h_table.iloc[i, j] = h

# Print the new table
display(h_table)
# Out:
#             rng:3.00  rng:5.00  rng:7.00  rng:9.00 rng:11.00 rng:13.00
# thld:0.015  0.039173  0.036591  0.034207  0.050385  0.048549  0.029679  \
# thld:0.020  0.025045  0.030091  0.030461  0.045659  0.034794   0.03205
# thld:0.025  0.019268  0.027973  0.024347  0.037988  0.027962  0.021159
# thld:0.030  0.018619  0.014398  0.019325   0.02809  0.022677  0.008637
# thld:0.035  0.020762  0.015164   0.01864  0.028413  0.016363 -0.000172
# thld:0.040  0.019727  0.008851  0.012208  0.028651  0.018307  0.000333
# thld:0.045  0.015512  0.006971  0.012965  0.025169  0.009885 -0.009019
# thld:0.050  0.009393 -0.001291  0.008771  0.027316  0.017403 -0.016403
# thld:0.100  0.003702 -0.042079 -0.013674  0.001872 -0.048453 -0.072641
#
#            rng:15.00 rng:17.00 rng:19.00 rng:21.00 rng:23.00 rng:25.00
# thld:0.015  0.026768  0.012967  0.019944  0.018995  0.014819  0.005094  \
# thld:0.020  0.012274  0.001826  0.009772  0.008675   0.02682  0.013151
# thld:0.025  0.007928 -0.007687  0.002679  0.004836  0.016411  0.015603
# thld:0.030  0.003697 -0.013395  0.003903  0.017744  0.014217   0.00998
# thld:0.035    -0.009 -0.009833  -0.00182  0.019292  -0.00257  0.000113
# thld:0.040 -0.014653 -0.014085 -0.016435  0.022296  0.001736 -0.010323
# thld:0.045 -0.015615 -0.015201 -0.015133  0.005046 -0.009212 -0.024948
# thld:0.050  -0.03155 -0.026105 -0.015705  0.003513 -0.010426 -0.040066
# thld:0.100 -0.086173 -0.082295 -0.053796 -0.054271 -0.052438 -0.124377
#
#            rng:27.00 rng:29.00 rng:31.00
# thld:0.015  0.005056  0.048297  0.026054
# thld:0.020  0.011395  0.041067  0.012392
# thld:0.025  0.006725  0.035544  0.016757
# thld:0.030  0.000494  0.033445  0.025249
# thld:0.035 -0.006323  0.034157  0.020083
# thld:0.040 -0.003698  0.036995  0.012428
# thld:0.045 -0.006731  0.027369 -0.002883
# thld:0.050 -0.021055  0.023504 -0.011728
# thld:0.100 -0.094312 -0.096664  -0.14937

# %%
import matplotlib.pyplot as plt

sp_table = h_table.applymap(lambda x: f"{x:.5f}")
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

# Add table data
tbl = ax.table(cellText=sp_table.values, colLabels=sp_table.columns, rowLabels=sp_table.index, cellLoc = 'center', loc='center')

plt.savefig(f"./figures/tables/h_{table_name}_{eval_name}_{pattern_name}.svg", format='svg')
plt.show()
